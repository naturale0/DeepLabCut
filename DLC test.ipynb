# %%
import deeplabcut as dlc
import os

# %%
task = 'test'                      # Enter the name of your experiment Task
experimenter = 'test'              # Enter the name of the experimenter
video = ['./psh-video/m3v1mp4.mp4']  # Enter the paths of your videos you want to grab frames from.

path_config_file = dlc.create_new_project(task, experimenter, video,
                                          working_directory=os.getcwd(),
                                          copy_videos=False)
path_config_file
# Out:
# Project "C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24" already exists!
# Do you want to overwrite current project? **This action cannot be undone.**
#
# yes/noy
# Overwrite existing project: "C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24"
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-c257c69c1179> in <module>
#       5 path_config_file = dlc.create_new_project(task, experimenter, video,
#       6                                           working_directory=os.getcwd(),
# ----> 7                                           copy_videos=False)
#       8 path_config_file
#
# ~\Desktop\DeepLabCut\deeplabcut\create_project\new.py in create_new_project(project, experimenter, videos, working_directory, copy_videos, videotype)
#      74         else:
#      75             print(f'Overwrite existing project: "{project_path}"')
# ...

# %%
# %matplotlib inline

dlc.extract_frames(path_config_file)
# Out:
# C:\Users\user\Desktop\DeepLabCut\deeplabcut\generate_training_dataset\frame_extraction.py:101: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(ymlfile)
# Config file read successfully.
# Do you want to extract (perhaps additional) frames for video: psh-video\m3v1mp4.mp4 ?
# yes/noy
# Extracting frames based on kmeans ...
# Kmeans-quantization based extracting of frames from 0.0  seconds to 77.67  seconds.
# Extracting and downsampling... 2330  frames from the video.
# 2330it [00:05, 409.71it/s]
# Kmeans clustering ... (this might take a while)
#
# Frames were selected.
# You can now label the frames using the function 'label_frames' (if you extracted enough frames for all videos).

# %%
# %gui wx
dlc.label_frames(path_config_file)
# Out:
# Cannot activate multiple GUI eventloops
# Cannot activate multiple GUI eventloops
# Cannot activate multiple GUI eventloops
# You can now check the labels, using 'check_labels' before proceeding. Then, you can use the function 'create_training_dataset' to create the training dataset.

# %%
dlc.check_labels(path_config_file)
# Out:
# Creating images with labels by test.
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\labeled-data\m3v1mp4_labeled  already exists!
# They are stored in the following folder: C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\labeled-data\m3v1mp4_labeled.
# If all the labels are ok, then use the function 'create_training_dataset' to create the training dataset!

# %%
dlc.create_training_dataset(path_config_file)
# Out:
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\training-datasets\iteration-0\UnaugmentedDataSet_testApr24  already exists!
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\dlc-models\iteration-0\testApr24-trainset95shuffle1  already exists!
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\dlc-models\iteration-0\testApr24-trainset95shuffle1//train  already exists!
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\dlc-models\iteration-0\testApr24-trainset95shuffle1//test  already exists!
# The training dataset is successfully created. Use the function 'train_network' to start training. Happy training!

# %%
dlc.train_network(path_config_file)
# Out:
# Config:
# {'all_joints': [[0], [1], [2], [3]],
#  'all_joints_names': ['Hand', 'Finger1', 'Finger2', 'Joystick'],
#  'batch_size': 1,
#  'bottomheight': 400,
#  'crop': True,
#  'crop_pad': 0,
#  'cropratio': 0.4,
#  'dataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_testApr24\\test_test95shuffle1.mat',
#  'dataset_type': 'default',
#  'display_iters': 1,
#  'fg_fraction': 0.25,
#  'global_scale': 0.8,
#  'init_weights': 'C:\\Users\\user\\Desktop\\DeepLabCut\\deeplabcut\\pose_estimation_tensorflow\\models\\pretrained\\resnet_v1_50.ckpt',
#  'intermediate_supervision': False,
#  'intermediate_supervision_layer': 12,
#  'leftwidth': 400,
#  'location_refinement': True,
#  'locref_huber_loss': True,
#  'locref_loss_weight': 0.05,
#  'locref_stdev': 7.2801,
#  'log_dir': 'log',
#  'max_input_size': 1500,
#  'mean_pixel': [123.68, 116.779, 103.939],
#  'metadataset': 'training-datasets\\iteration-0\\UnaugmentedDataSet_testApr24\\Documentation_data-test_95shuffle1.pickle',
# ...

# %%
dlc.evaluate_network(path_config_file)
# Out:
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24/evaluation-results/  already exists!
# C:\Users\user\Desktop\DeepLabCut\deeplabcut\pose_estimation_tensorflow\config.py:46: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\evaluation-results\iteration-0\testApr24-trainset95shuffle1  already exists!
# Running  DeepCut_resnet50_testApr24shuffle1_112  with # of trainingiterations: 112
# This net has already been evaluated!
# The network is evaluated and the results are stored in the subdirectory 'evaluation_results'.
# If it generalizes well, choose the best model for prediction and update the config file with the appropriate index for the 'snapshotindex'.
# Use the function 'analyze_video' to make predictions on new videos.
# ...

# %%
dlc.analyze_videos(path_config_file, video)
# Out:
# Using snapshot-112 for model C:\Users\user\Desktop\DeepLabCut\test-test-2019-04-24\dlc-models\iteration-0\testApr24-trainset95shuffle1
# WARNING:tensorflow:From C:\Users\user\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\user\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\DeepLabCut'

# %%
os.chdir("DeepLabCut/")

# %%
dlc.create_labeled_video(path_config_file, video)
os.getcwd()
# Out:
# Starting %  psh-video ['./psh-video/m3v1mp4.mp4']
# Loading  ./psh-video/m3v1mp4.mp4 and data.
# The video was not analyzed with this scorer: DeepCut_resnet50_testApr24shuffle1_112
# Other scorers were found, however: ['m3v1mp4DeepCut_resnet50_testApr24shuffle1_112.h5']
# Creating labeled video for: DeepCut_resnet50_testApr24shuffle1_112  instead.
# False 0 640 0 480
# 0
# Error: %s <class 'cv2.VideoWriter'> returned a result with an error set
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-2248223df964> in <module>
# ----> 1 dlc.create_labeled_video(path_config_file, video)
#       2 os.getcwd()
#
# ~\Desktop\DeepLabCut\deeplabcut\utils\make_labeled_video.py in create_labeled_video(config, videos, videotype, shuffle, trainingsetindex, save_frames, Frames2plot, delete, displayedbodyparts, codec, outputframerate, destfolder)
# ...

# %%
dlc.plot_trajectories(path_config_file, video, showfigures=False)
# Out:
# ./psh-video/m3v1mp4.mp4
# Starting %  psh-video ['./psh-video/m3v1mp4.mp4']
# psh-video  already exists!
# psh-video\plot-poses  already exists!
# psh-video\plot-poses\m3v1mp4  already exists!
# Delete and rewrite folder "psh-video\plot-poses\m3v1mp4" and all its files? **This action cannot be undone.**
#
# yes/noy
# Overwrite existing folder: "psh-video\plot-poses\m3v1mp4"
# Loading  ./psh-video/m3v1mp4.mp4 and data.
# Plots created! Please check the directory "plot-poses" within the video directory
